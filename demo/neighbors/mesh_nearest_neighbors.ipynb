# %%
import pyclesperanto_prototype as cle
from numpy import random
from skimage.io import imshow

# %%
pointlist = cle.push_zyx(random.random((2,25)) * 100) 
print(pointlist)
# Out:
# [[82.07392   61.743324  24.044563  23.401918  58.83031   14.841625
#   65.728065  20.56742   56.170868  50.251217  92.97353   86.1744
#   21.599112  14.710198  14.923596  92.96172   66.648     21.121948
#   91.87506   96.426445  34.786064  61.918674  54.48577   69.78287
#   18.594513 ]
#  [ 8.753924   1.4185699 52.231815  63.972008  74.71437   77.4825
#   60.40445   82.40314   54.29485   39.64036   15.57555   48.74332
#   87.68647   93.11849   38.735508  67.78253   48.96325   35.488842
#   93.80854   83.83424   16.82569   92.00881   22.90601   28.873756
#    2.194068 ]]

# %%
labelled_spots = cle.pointlist_to_labelled_spots(pointlist)
imshow(cle.pull_zyx(labelled_spots))
# Out:
# c:\users\rober\miniconda3\lib\site-packages\pyopencl\__init__.py:252: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   warn("Non-empty compiler output encountered. Set the "
# c:\users\rober\miniconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# c:\users\rober\miniconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
cells = cle.extend_labeling_via_voronoi(labelled_spots)
membranes = cle.detect_label_edges(cells)
imshow(cle.pull_zyx(membranes))
# Out:
# c:\users\rober\miniconda3\lib\site-packages\pyopencl\__init__.py:252: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   warn("Non-empty compiler output encountered. Set the "

# %%
nearest_neighbors_mesh = cle.draw_mesh_between_n_closest_labels(cells, n=1)
imshow(cle.pull_zyx(nearest_neighbors_mesh))

# %%
two_nearest_neighbors_mesh = cle.draw_mesh_between_n_closest_labels(cells, n=2)
imshow(cle.pull_zyx(two_nearest_neighbors_mesh))

# %%
three_nearest_neighbors_mesh = cle.draw_mesh_between_n_closest_labels(cells, n=3)
imshow(cle.pull_zyx(three_nearest_neighbors_mesh))

# %%
four_nearest_neighbors_mesh = cle.draw_mesh_between_n_closest_labels(cells, n=4)
imshow(cle.pull_zyx(four_nearest_neighbors_mesh))

# %%
ten_nearest_neighbors_mesh = cle.draw_mesh_between_n_closest_labels(cells, n=10)
imshow(cle.pull_zyx(ten_nearest_neighbors_mesh))
