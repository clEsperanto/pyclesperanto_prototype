# %%
import numpy as np
import pyclesperanto_prototype as cle

cle.get_device()
# Out:
# <gfx90c on Platform: AMD Accelerated Parallel Processing (15 refs)>

# %% [markdown]
# Our starting point is a label image and another label image, where some of the labels in the first image are selected from.

# %%
label_image = cle.artificial_tissue_2d()
cle.imshow(label_image, labels=True)

# %%
random_vector = np.random.random((1, label_image.max() + 1))
some_labels = cle.exclude_labels_outside_size_range()
