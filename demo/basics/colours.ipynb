# %%
import pyclesperanto_prototype as cle
import matplotlib.pyplot as plt
import stackview

import numpy as np

# %%
image = np.asarray([[0,1,2,3,4,5]])

# %%
cle.imshow(image, labels=True)

# %%
stackview.insight(image.astype(np.int32))
# Out:
# StackViewNDArray([[0, 1, 2, 3, 4, 5]])

# %%
plt.plot([1,1])
plt.plot([2,2])
plt.plot([3,3])
plt.plot([4,4])
plt.plot([5,5])
