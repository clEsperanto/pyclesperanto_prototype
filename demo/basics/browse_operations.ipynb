# %% [markdown]
# # Function overview
# Print out all pyclesperanto functions and their parameters

# %%
import pyclesperanto_prototype as cle

def list_operations(search_term = None):
    ops = cle.operations(search_term)
    for name in ops:
        op = ops[name]
        func = cle.operation(name)

        if hasattr(func, 'fullargspec'):
            print(name + "(" + str(func.fullargspec.args).replace('[','').replace(']','').replace('\'','') + ")")
        else:
            print(name)

list_operations()
# Out:
# absolute(source, destintation)
# absolute_difference(source1, source2, destination)
# add_image_and_scalar(source, destination, scalar)
# add_images(summand1, summand2, destination)
# add_images_weighted(summand1, summand2, destination, factor1, factor2)
# artificial_tissue_2d
# available_device_names
# average_distance_of_n_closest_neighbors_map(labels, distance_map, n)
# average_distance_of_n_closest_points(distance_matrix, distance_vector_destination, n)
# average_distance_of_n_far_off_distances(distance_matrix, distance_vector_destination, n)
# average_distance_of_n_far_off_points(distance_matrix, distance_vector_destination, n)
# average_distance_of_n_shortest_distances(distance_matrix, distance_vector_destination, n)
# average_distance_of_touching_neighbors(distance_matrix, touch_matrix, average_distancelist_destination)
# average_neighbor_distance_map(labels, distance_map)
# binary_and(operand1, operand2, destination)
# binary_edge_detection(source, destination)
# binary_intersection(operand1, operand2, destination)
# binary_not(source, destination)
# binary_or(operand1, operand2, destination)
# binary_subtract(minuend, subtrahend, destination)
# binary_union(operand1, operand2, destination)
# binary_xor(operand1, operand2, destination)
# block_enumerate(src, src_sums, dst, blocksize)
# bottom_hat_box(input, destination, radius_x, radius_y, radius_z)
# bottom_hat_sphere(input, destination, radius_x, radius_y, radius_z)
# bounding_box(source)
# center_of_mass(source)
# centroids_of_background_and_labels(source, pointlist_destination, regionprops, use_gpu)
# centroids_of_labels(labels_source, pointlist_destination, include_background, regionprops, use_gpu)
# cl_info
# close_index_gaps_in_label_map(input, output, blocksize)
# combine_horizontally(stack1, stack2, destination)
# combine_vertically(stack1, stack2, destination)
# concatenate_stacks(stack1, stack2, destination)
# connected_components_labeling_box(binary_input, labeling_destination, flagged_nonzero_minimum_filter)
# connected_components_labeling_diamond(binary_input, labeling_destination)
# convolve(source, convolution_kernel, destination)
# copy(source, destination)
# copy_slice(source, destination, slice_index)
# count_touching_neighbors(touch_matrix, touching_neighbors_count_destination)
# create
# create_2d_xy
# create_2d_yx
# create_2d_zx
# create_2d_zy
# create_from_pointlist
# create_image
# create_like
# create_matrix_from_pointlists
# create_none
# create_pointlist_from_labelmap
# create_square_matrix_from_labelmap
# create_square_matrix_from_pointlist
# create_square_matrix_from_two_labelmaps
# create_vector_from_labelmap
# create_vector_from_square_matrix
# create_zyx
# crop(input, output, start_x, start_y, start_z, width, height, depth)
# degrees_to_radians(source, destination)
# detect_label_edges(label_source, binary_destination)
# detect_maxima_box(source, destination, radius_x, radius_y, radius_z)
# detect_minima_box(source, destination, radius_x, radius_y, radius_z)
# difference_of_gaussian(input, destination, sigma1_x, sigma1_y, sigma1_z, sigma2_x, sigma2_y, sigma2_z)
# dilate_box(source, destination)
# dilate_box_slice_by_slice(src, dst)
# dilate_sphere(source, destination)
# dilate_sphere_slice_by_slice(src, dst)
# distance_matrix_to_mesh(pointlist, distance_matrix, mesh_destination, maximum_distance)
# divide_by_gaussian_background(input, destination, sigma_x, sigma_y, sigma_z)
# divide_images(divident, divisor, destination)
# downsample_slice_by_slice_half_median(source, destination)
# downsample_xy_by_half_median(source, destination)
# draw_angle_mesh_between_touching_labels(labels, angle_mesh_destination)
# draw_box(destination, x, y, z, width, height, depth, value)
# draw_distance_mesh_between_touching_labels(labels, distance_mesh_destination)
# draw_line(destination, x1, y1, z1, x2, y2, z2, thickness, value)
# draw_mesh_between_n_closest_labels(labels, mesh_target, n)
# draw_mesh_between_proximal_labels(labels, mesh_target, maximum_distance)
# draw_mesh_between_touching_labels(labels, distance_mesh_destination)
# draw_sphere(destination, x, y, z, radius_x, radius_y, radius_z, value)
# empty_image
# empty_image_like
# equal(source1, source2, destination)
# equal_constant(source, destination, constant)
# erode_box(source, destination)
# erode_box_slice_by_slice(source, destination)
# erode_sphere(source, destination)
# erode_sphere_slice_by_slice(source, destination)
# euclidean_distance_from_label_centroid_map(labels, centroids_pointlist, distance_map_destination)
# exclude_labels(binary_flaglist, label_map_input, label_map_destination)
# exclude_labels_on_edges(label_map_input, label_map_destination)
# exclude_labels_out_of_size_range(input, destination, minimum_size, maximum_size)
# exclude_labels_outside_size_range(input, destination, minimum_size, maximum_size)
# exclude_labels_with_values_out_of_range(values_vector, label_map_input, label_map_destination, minimum_value_range, maximum_value_range)
# exclude_labels_with_values_within_range(values_vector, label_map_input, label_map_destination, minimum_value_range, maximum_value_range)
# execute
# execute_separable_kernel
# exponential(source, destination)
# extend_labeling_via_voronoi(labeling_source, labeling_destination)
# extend_labels_with_maximum_radius(labeling_source, labeling_destination, radius)
# flag_existing_intensities(label_src, flag_vector_destination)
# flag_existing_labels(label_src, flag_vector_destination)
# flip(source, destination, flip_x, flip_y, flip_z)
# gamma_correction(source, target, gamma)
# gaussian_blur(source, destination, sigma_x, sigma_y, sigma_z)
# generate_angle_matrix(coordinate_list1, coordinate_list2, angle_matrix_destination)
# generate_binary_overlap_matrix(label_map1, label_map2, binary_overlap_matrix_destination)
# generate_distance_matrix(coordindate_list1, coordinate_list2, distance_matrix_destination)
# generate_touch_matrix(label_map, touch_matrix_destination)
# get_device
# gradient_x(source, destination)
# gradient_y(source, destination)
# gradient_z(source, destination)
# greater(source1, source2, destination)
# greater_constant(source, destination, constant)
# greater_or_equal(source1, source2, destination)
# greater_or_equal_constant(source, destination, constant)
# histogram(source, destination, num_bins, minimum_intensity, maximum_intensity, determine_min_max)
# imread
# imshow
# invert(source, destination)
# jaccard_index
# label_centroids_to_pointlist(labels_source, pointlist_destination, include_background, regionprops, use_gpu)
# label_maximum_extension_map(labels, destination)
# label_maximum_extension_ratio_map(labels, destination)
# label_maximum_intensity_map(intensity_image, labels, maximum_intensity_map)
# label_mean_extension_map(labels, destination)
# label_mean_intensity_map(input, label_map, destination)
# label_minimum_intensity_map(intensity_image, labels, minimum_intensity_map)
# label_pixel_count_map(input, destination)
# label_spots(input_spots, labelled_spots_destination)
# label_standard_deviation_intensity_map(intensity_image, labels, standard_deviation_intensity_map)
# label_to_mask(source, destination, constant)
# labelled_spots_to_pointlist(input_labelled_spots, destination_pointlist)
# laplace_box(input, destination)
# laplace_diamond(source, destination)
# local_maximum_touching_neighbor_count_map(input, destination)
# local_mean_touching_neighbor_count_map(input, destination)
# local_median_touching_neighbor_count_map(input, destination)
# local_minimum_touching_neighbor_count_map(input, destination)
# local_standard_deviation_touching_neighbor_count_map(input, destination)
# local_threshold(source1, source2, destination)
# logarithm(source, destination)
# mask(source, mask, destination)
# mask_label(source, label_map, destination, label_index)
# maximum_box(source, destination, radius_x, radius_y, radius_z)
# maximum_distance_of_touching_neighbors(distance_matrix, touch_matrix, distancelist_destination)
# maximum_image_and_scalar(source, destination, scalar)
# maximum_images(source1, source2, destination)
# maximum_of_all_pixels(source)
# maximum_of_touching_neighbors(values, touch_matrix, maximum_values_destination)
# maximum_sphere(source, destination, radius_x, radius_y, radius_z)
# maximum_x_projection(source, destination_max)
# maximum_y_projection(source, destination_max)
# maximum_z_projection(source, destination_max)
# mean_box(source, destination, radius_x, radius_y, radius_z)
# mean_of_all_pixels(source)
# mean_of_touching_neighbors(values, touch_matrix, mean_values_destination)
# mean_sphere(source, destination, radius_x, radius_y, radius_z)
# mean_squared_error(source1, source2)
# mean_x_projection(source, destination)
# mean_y_projection(source, destination)
# mean_z_projection(source, destination)
# median_of_touching_neighbors(values, touch_matrix, median_values_destination)
# merge_touching_labels(labels_input, labels_destination)
# minimum_box(source, destination, radius_x, radius_y, radius_z)
# minimum_distance_of_touching_neighbors(distance_matrix, touch_matrix, distancelist_destination)
# minimum_image_and_scalar(source, destination, scalar)
# minimum_images(source1, source2, destination)
# minimum_of_all_pixels(source)
# minimum_of_masked_pixels(source, mask)
# minimum_of_touching_neighbors(values, touch_matrix, minimum_values_destination)
# minimum_sphere(source, destination, radius_x, radius_y, radius_z)
# minimum_x_projection(source, destination_min)
# minimum_y_projection(source, destination_min)
# minimum_z_projection(source, destination_min)
# mode_of_touching_neighbors(src_values, touch_matrix, dst_values)
# multiply_image_and_coordinate(source, destination, dimension)
# multiply_image_and_scalar(source, destination, scalar)
# multiply_images(factor1, factor2, destination)
# multiply_matrix
# n_closest_points(distance_matrix, indexlist_destination, n)
# neighbors_of_neighbors(touch_matrix, neighbor_matrix_destination)
# nonzero_maximum_box
# nonzero_maximum_diamond
# nonzero_minimum_box
# nonzero_minimum_diamond
# not_equal(source1, source2, destination)
# not_equal_constant(source, destination, constant)
# onlyzero_overwrite_maximum_box
# onlyzero_overwrite_maximum_diamond
# operation
# operations
# paste(source, destination, destination_x, destination_y, destination_z)
# point_index_list_to_mesh(pointlist, indexlist, mesh_destination)
# pointlist_to_labelled_spots(pointlist, spots_destination)
# power(source, destination, exponent)
# power_images(input, exponent, destination)
# pull
# pull_zyx
# push
# push_regionprops
# push_regionprops_column
# push_zyx
# radians_to_degrees(source, destination)
# radius_to_kernel_size
# reduce_stack(input, destination, reduction_factor, offset)
# replace_intensities(input, new_values_vector, destination)
# replace_intensity(input, destination, value_to_replace, value_replacement)
# resample(source, destination, factor_x, factor_y, factor_z, linear_interpolation)
# select_device
# set(source, scalar)
# set_column(source, column_index, value)
# set_device_scoring_key
# set_image_borders(destination, value)
# set_non_zero_pixels_to_pixel_index(input, output, offset)
# set_nonzero_pixels_to_pixelindex(input, output, offset)
# set_plane(source, plane_index, value)
# set_ramp_x(source)
# set_ramp_y(source)
# set_ramp_z(source)
# set_row(source, row_index, value)
# set_wait_for_kernel_finish
# set_where_x_equals_y(source, value)
# set_where_x_greater_than_y(source, value)
# set_where_x_smaller_than_y(source, value)
# sigma_to_kernel_size
# smaller(source1, source2, destination)
# smaller_constant(source, destination, constant)
# smaller_or_equal(source1, source2, destination)
# smaller_or_equal_constant(source, destination, constant)
# sobel(source, destination)
# sorensen_dice_coefficient(source1, source2)
# spots_to_pointlist(input_spots, destination_pointlist)
# squared_difference(source1, source2, destination)
# standard_deviation_of_touching_neighbors(values, touch_matrix, standard_deviation_values_destination)
# standard_deviation_z_projection(source, destination)
# statistics_of_background_and_labelled_pixels(input, labelmap, measure_shape, extra_properties, use_gpu)
# statistics_of_image(image, use_gpu)
# statistics_of_labelled_pixels(input, labelmap, measure_shape, extra_properties, use_gpu)
# subtract_gaussian_background(input, destination, sigma_x, sigma_y, sigma_z)
# subtract_image_from_scalar(input, destination, scalar)
# subtract_images(subtrahend, minuend, destination)
# sum_of_all_pixels(source)
# sum_reduction_x(src, dst, blocksize)
# sum_x_projection(source, destination)
# sum_y_projection(source, destination)
# sum_z_projection(source, destination)
# threshold(source, destination, constant)
# threshold_otsu(input, destination)
# top_hat_box(input, destination, radius_x, radius_y, radius_z)
# top_hat_sphere(input, destination, radius_x, radius_y, radius_z)
# touch_matrix_to_mesh(pointlist, touch_matrix, mesh_destination)
# touching_neighbor_count_map(input, destination)
# transpose_xy(input, destination)
# transpose_xz(input, destination)
# transpose_yz(input, destination)
# undefined_to_zero(source, destination)
# voronoi_labeling(binary_source, labeling_destination)
# write_values_to_positions(positions_and_values, destination)

# %% [markdown]
# Count operations

# %%
print(len(cle.operations()))
# Out:
# 260

# %% [markdown]
# List all operations in a given category

# %%
list_operations(['binarize'])
# Out:
# detect_label_edges(label_source, binary_destination)
# detect_maxima_box(source, destination, radius_x, radius_y, radius_z)
# detect_minima_box(source, destination, radius_x, radius_y, radius_z)
# equal(source1, source2, destination)
# equal_constant(source, destination, constant)
# greater(source1, source2, destination)
# greater_constant(source, destination, constant)
# greater_or_equal(source1, source2, destination)
# greater_or_equal_constant(source, destination, constant)
# label_to_mask(source, destination, constant)
# local_threshold(source1, source2, destination)
# not_equal(source1, source2, destination)
# not_equal_constant(source, destination, constant)
# smaller(source1, source2, destination)
# smaller_constant(source, destination, constant)
# smaller_or_equal(source1, source2, destination)
# smaller_or_equal_constant(source, destination, constant)
# threshold(source, destination, constant)
# threshold_otsu(input, destination)

# %% [markdown]
# List all operations which are in two categories

# %%
list_operations(['binarize', 'combine'])
# Out:
# equal(source1, source2, destination)
# greater(source1, source2, destination)
# greater_or_equal(source1, source2, destination)
# local_threshold(source1, source2, destination)
# not_equal(source1, source2, destination)
# smaller(source1, source2, destination)
# smaller_or_equal(source1, source2, destination)

# %% [markdown]
# print out the documentation of a given function

# %%
print(cle.detect_label_edges.__doc__)
# Out:
# Takes a labelmap and returns an image where all pixels on label edges
#     are set to 1 and all other pixels to 0.
#
#     Parameters
#     ----------
#     label_map : Image
#     edge_image_destination : Image
#
#     Returns
#     -------
#     edge_image_destination
#
#     Examples
#     --------
#     >>> import pyclesperanto_prototype as cle
#     >>> cle.detect_label_edges(label_map, edge_image_destination)
#
#     References
#     ----------
#     .. [1] https://clij.github.io/clij2-docs/reference_detectLabelEdges
